# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
matplotlib.style.use('seaborn')

# %%
panel = pd.read_csv("Datanew.csv")

# %%
panel.head(4)
# Out:
#            city  year  Civilian employed population 16 years and ove  \
# 0  Portland, OR  2005                                         263362
# 1  Portland, OR  2006                                         284436
# 2  Portland, OR  2007                                         288530
# 3  Portland, OR  2008                                         297337
#
#    Agriculture, forestry, fishing and hunting, and mining  Construction  \
# 0                                               1532              14616
# 1                                               1933              16347
# 2                                               2957              17367
# 3                                               1311              15191
#
#    Manufacturing  Wholesale trade  Retail trade  \
# 0          27405             9473         28702
# 1          29369            10745         29881
# 2          28382             9810         31787
# 3          30398             9711         30908
#
# ...

# %%
data = panel.copy()

# %%
data.columns = ['city', 'year', 'Total', 'Agriculture', 'Construction', 'Manufacturing', 'Wholesale', 'Retail ', 
                'Transportation ', 'Information', 'FIRE', 'STEM', 'Educational', 'Arts', 'Other non-public Services', 'Public Services']

# %%
data.head(4)
# Out:
#            city  year   Total  Agriculture  Construction  Manufacturing  \
# 0  Portland, OR  2005  263362         1532         14616          27405
# 1  Portland, OR  2006  284436         1933         16347          29369
# 2  Portland, OR  2007  288530         2957         17367          28382
# 3  Portland, OR  2008  297337         1311         15191          30398
#
#    Wholesale  Retail   Transportation   Information   FIRE   STEM  \
# 0       9473    28702            11812         7174  21026  35224
# 1      10745    29881            12213         7164  20455  40195
# 2       9810    31787            15764         8886  17740  38721
# 3       9711    30908            15430         8560  20131  42049
#
#    Educational   Arts  Other non-public Services Public Services
# 0        56213  28163                      11909           10113
# 1        58992  32332                      14935            9875
# 2        60284  30480                      15474           10878
# ...

# %%
data.to_csv('edata.csv')
